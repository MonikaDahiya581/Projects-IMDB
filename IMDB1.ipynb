# %%
# importing the required libraries
from bs4 import BeautifulSoup,SoupStrainer
import requests
import pandas as pd
import numpy as np

# %%
#Send get request to the webpage server to get the source code of the page
url="https://www.imdb.com/search/title/?genres=action&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=XZ8X52H1R40B7KG5SNZ9&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1"
IMBD = requests.get(url)
soup = BeautifulSoup(IMBD.content, 'html.parser')

# %%
movie_name =[]
stars =[] 
votes =[] 
Genre =[] 
gross_collection =[] 
popularity = [] 
Certification =[]

# %%
movie_data = soup.findAll('div',attrs = {'class': 'lister-item mode-advanced'})

# %%
for store in movie_data:
    name = store.h3.a.text
    movie_name.append(name)

# %%
print(len(movie_name))
# Out:
# 50

# %%
for store in movie_data:
    
    star = store.p.find('span', class_ = 'title-cast-item__actor')
    stars.append(star)
    
    value = store.find_all('span', attrs = {'name': 'nv'})
    
    vote = value[0].text
    votes.append(vote)
    
    grosses = value[1].text if len(value) >1 else '******'
    gross_collection.append(grosses)
    
    genre = store.p.find('span', class_='genre')
    Genre.append(genre)
    
    certificate = store.p.find('span', class_ ='certificate')
    Certification.append(certificate)

# %%
print(len(gross_collection))
# Out:
# 50

# %%
print(len(votes))
# Out:
# 50

# %%
np.count_nonzero(votes)
# Out:
# 50

# %%
print(len(Genre))
# Out:
# 50

# %%
print(len(Certification))
# Out:
# 50

# %%
print(len(stars))
# Out:
# 50

# %%
print(len(movie_name))
# Out:
# 50

# %%
df = pd.DataFrame({'Movie_name':movie_name,'Stars':stars,'Votes':votes,'Genres':Genre,'Gross_collection':gross_collection,'Certificates':Certification})

# %%
df
# Out:
#                                            Movie_name Stars      Votes
# 0                                     The Dark Knight  None  2,715,150  \
# 1       The Lord of the Rings: The Return of the King  None  1,885,252
# 2                                           Inception  None  2,410,210
# 3   The Lord of the Rings: The Fellowship of the Ring  None  1,914,004
# 4               The Lord of the Rings: The Two Towers  None  1,701,713
# 5                                          The Matrix  None  1,955,718
# 6      Star Wars: Episode V - The Empire Strikes Back  None  1,319,755
# 7                                     Soorarai Pottru  None    119,406
# 8                                           Star Wars  None  1,392,273
# 9                          Terminator 2: Judgment Day  None  1,121,961
# 10                               Shichinin no samurai  None    352,534
# 11                                            Seppuku  None     60,836
# 12                                         Sita Ramam  None     59,627
# 13                                               Léon  None  1,188,096
# 14                                          Gladiator  None  1,534,628
# 15                                  Avengers: Endgame  None  1,177,727
# 16                  Spider-Man: Into the Spider-Verse  None    562,534
# 17                            Raiders of the Lost Ark  None    985,261
# 18                             Avengers: Infinity War  None  1,121,251
# 19                                           Oldeuboi  None    595,588
# 20                              The Dark Knight Rises  None  1,739,877
# 21                                             Aliens  None    731,901
# 22                                             Kaithi  None     35,992
# 23                                             Asuran  None     31,144
# 24                     Guardians of the Galaxy Vol. 3  None    131,912
# 25                                               Heat  None    674,601
# 26                                  Top Gun: Maverick  None    586,152
# 27         Star Wars: Episode VI - Return of the Jedi  None  1,076,523
# 28                                      Mononoke-hime  None    406,220
# 29                                 North by Northwest  None    334,331
# 30                                            Kantara  None     95,166
# 31                                             Dangal  None    197,087
# 32                                   K.G.F: Chapter 2  None    139,442
# 33                                             Vikram  None     63,708
# 34                                           Ratsasan  None     46,880
# 35                                          Shershaah  None    124,638
# 36                               John Wick: Chapter 4  None    155,003
# 37                            Spider-Man: No Way Home  None    794,913
# 38                                      Jurassic Park  None  1,012,868
# 39                                               1917  None    619,756
# 40                                  Kill Bill: Vol. 1  None  1,139,744
# 41                 Indiana Jones and the Last Crusade  None    770,376
# 42                                      Batman Begins  None  1,501,754
# 43                                           Die Hard  None    900,666
# 44                                     V for Vendetta  None  1,140,022
# 45                 Kimetsu no Yaiba: Mugen Ressha-Hen  None     64,089
# 46                                       Vikram Vedha  None     47,534
# 47                                                Ran  None    129,009
# 48                        Baahubali 2: The Conclusion  None    106,556
# 49                                            Yôjinbô  None    125,769
#
#                                           Genres Gross_collection Certificates
# 0           [\nAction, Crime, Drama            ]         $534.86M         [UA]
# 1       [\nAction, Adventure, Drama            ]         $377.85M          [U]
# 2      [\nAction, Adventure, Sci-Fi            ]         $292.58M         [UA]
# 3       [\nAction, Adventure, Drama            ]         $315.54M          [U]
# 4       [\nAction, Adventure, Drama            ]         $342.55M         [UA]
# 5                 [\nAction, Sci-Fi            ]         $171.48M          [A]
# 6     [\nAction, Adventure, Fantasy            ]         $290.48M         [UA]
# 7                  [\nAction, Drama            ]           ******          [U]
# 8     [\nAction, Adventure, Fantasy            ]         $322.74M          [U]
# 9                 [\nAction, Sci-Fi            ]         $204.84M          [A]
# 10                 [\nAction, Drama            ]           $0.27M          [U]
# 11        [\nAction, Drama, Mystery            ]           ******         None
# 12        [\nAction, Drama, Mystery            ]           ******          [U]
# 13          [\nAction, Crime, Drama            ]          $19.50M          [A]
# 14      [\nAction, Adventure, Drama            ]         $187.71M         [UA]
# 15      [\nAction, Adventure, Drama            ]         $858.37M         [UA]
# 16  [\nAnimation, Action, Adventure            ]         $190.24M          [U]
# 17             [\nAction, Adventure            ]         $248.16M          [A]
# 18     [\nAction, Adventure, Sci-Fi            ]         $678.82M         [UA]
# 19        [\nAction, Drama, Mystery            ]           $0.71M          [A]
# 20       [\nAction, Drama, Thriller            ]         $448.14M         [UA]
# 21     [\nAction, Adventure, Sci-Fi            ]          $85.16M          [U]
# 22      [\nAction, Adventure, Crime            ]           ******         [UA]
# 23                 [\nAction, Drama            ]           ******         [UA]
# 24     [\nAction, Adventure, Comedy            ]           ******         [UA]
# 25          [\nAction, Crime, Drama            ]          $67.44M          [A]
# 26                 [\nAction, Drama            ]         $718.73M         [UA]
# 27    [\nAction, Adventure, Fantasy            ]         $309.13M          [U]
# 28  [\nAnimation, Action, Adventure            ]           $2.38M          [U]
# 29    [\nAction, Adventure, Mystery            ]          $13.28M          [U]
# 30      [\nAction, Adventure, Drama            ]           ******         [UA]
# 31      [\nAction, Biography, Drama            ]          $12.39M          [U]
# 32          [\nAction, Crime, Drama            ]           $6.60M         [UA]
# 33       [\nAction, Crime, Thriller            ]           ******         [UA]
# 34          [\nAction, Crime, Drama            ]           ******         [UA]
# 35      [\nAction, Biography, Drama            ]           ******         [UA]
# 36       [\nAction, Crime, Thriller            ]           ******          [A]
# 37    [\nAction, Adventure, Fantasy            ]         $804.75M         [UA]
# 38     [\nAction, Adventure, Sci-Fi            ]         $402.45M         [UA]
# 39            [\nAction, Drama, War            ]         $159.23M          [R]
# 40          [\nAction, Crime, Drama            ]          $70.10M          [A]
# 41             [\nAction, Adventure            ]         $197.17M          [U]
# 42          [\nAction, Crime, Drama            ]         $206.85M         [UA]
# 43              [\nAction, Thriller            ]          $83.01M          [A]
# 44         [\nAction, Drama, Sci-Fi            ]          $70.51M         [UA]
# 45  [\nAnimation, Action, Adventure            ]          $47.70M         [UA]
# 46          [\nAction, Crime, Drama            ]           ******         [UA]
# 47            [\nAction, Drama, War            ]           $4.14M  [Not Rated]
# 48                 [\nAction, Drama            ]          $20.19M         [UA]
# 49       [\nAction, Drama, Thriller            ]           ******          [U]
